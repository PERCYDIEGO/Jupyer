# %%
import pandas as pd
import random as rnd
import re
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import os
# %matplotlib inline
sns.set(color_codes=True)

# %%
os.chdir('F:/Carpeta Drive/Python/Base')

# %%
df=pd.read_csv('data.csv', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
df[df['Country'] =="France"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8408 entries, 26 to 541908
# Data columns (total 8 columns):
# InvoiceNo      8408 non-null object
# StockCode      8408 non-null object
# Description    8408 non-null object
# Quantity       8408 non-null int64
# InvoiceDate    8408 non-null object
# UnitPrice      8408 non-null float64
# CustomerID     8342 non-null float64
# Country        8408 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 591.2+ KB

# %%
len(df[df['Country'] =="France"]['InvoiceNo'].unique())
# Out:
# 392

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                                          antecedants  \
# 0  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 1  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 2  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 3                      (SET/6 RED SPOTTY PAPER CUPS)
# 4               (SET/20 RED RETROSPOT PAPER NAPKINS)
#
#                                          consequents  antecedent support  \
# 0                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 1               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
# 2                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 3  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.137755
# 4  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...            0.132653
#
#    consequent support  support  confidence      lift  leverage  conviction
# 0            0.127551  0.09949    0.975000  7.644000  0.086474   34.897959
# 1            0.132653  0.09949    0.812500  6.125000  0.083247    4.625850
# 2            0.137755  0.09949    0.975000  7.077778  0.085433   34.489796
# 3            0.102041  0.09949    0.722222  7.077778  0.085433    3.232653
# 4            0.122449  0.09949    0.750000  6.125000  0.083247    3.510204

# %%
df_rules=pd.DataFrame(rules.iloc[:,[0,1,4,5,6]])
df_rules.columns=["From","To","Support","Confidence","Lift"]
df_rules['Support']=df_rules['Support']*100
df_rules['Support']=df_rules["Support"].map('{:,.2f}%'.format)
df_rules['Confidence']=df_rules['Confidence']*100
df_rules['Confidence']=df_rules["Confidence"].map('{:,.2f}%'.format)

# %%
df_rules.sort_values(by=['Confidence', 'Support','Lift'],ascending=False).head(10)
# Out:
#                                                  From  \
# 0   (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 2   (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 25                    (SET/6 RED SPOTTY PAPER PLATES)
# 24                      (SET/6 RED SPOTTY PAPER CUPS)
# 13                         (ALARM CLOCK BAKELIKE RED)
# 12                       (ALARM CLOCK BAKELIKE GREEN)
# 1   (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
# 21                         (ALARM CLOCK BAKELIKE RED)
# 5                     (SET/6 RED SPOTTY PAPER PLATES)
#
#                                                    To Support Confidence  \
# 0                     (SET/6 RED SPOTTY PAPER PLATES)   9.95%     97.50%
# 2                       (SET/6 RED SPOTTY PAPER CUPS)   9.95%     97.50%
# 25                      (SET/6 RED SPOTTY PAPER CUPS)  12.24%     96.00%
# 24                    (SET/6 RED SPOTTY PAPER PLATES)  12.24%     88.89%
# 13                       (ALARM CLOCK BAKELIKE GREEN)   7.91%     83.78%
# 12                         (ALARM CLOCK BAKELIKE RED)   7.91%     81.58%
# 1                (SET/20 RED RETROSPOT PAPER NAPKINS)   9.95%     81.25%
# 17               (SET/20 RED RETROSPOT PAPER NAPKINS)  10.20%     80.00%
# 21                        (ALARM CLOCK BAKELIKE PINK)   7.40%     78.38%
# 5   (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...   9.95%     78.00%
#
#         Lift
# 0   7.644000
# 2   7.077778
# 25  6.968889
# 24  6.968889
# 13  8.642959
# 12  8.642959
# 1   6.125000
# 17  6.030769
# 21  7.681081
# 5   7.644000
